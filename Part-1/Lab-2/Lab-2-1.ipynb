# %% [markdown]
# 1.3.1. Работа со списками
#
# Тип работы: Индивидуальная работа
#
# ---
#
# N человек, пронумерованных числами от 1 до N стоят в кругу. Они начинают считаться начиная с 1-го номера и K-й по счету человек выбывает из круга, после чего счет начинается со следующего за ним человека и следущий K-й по счету человек выбывает из круга и т.д. до тех пор пока не останется один человек, который выбывает из круга в последнюю очередь.
#
# Требуется написать функцию form_list(N, K), формирующую по заданным числам N и K список номеров людей, в порядке их выбывания из круга.
#
# ---
#
# **Входные аргументы**: N <= 50, K <=10.
#
# ---
#
# **Возврат функции**: список номеров людей в порядке выбывания из круга
#
# ---
#
# **Примеры**:
#
# - для N = 7, K =2 функция должна вернуть список [2, 4, 6, 1, 5, 3, 7]
#
# - для N = 12, K =3 функция должна вернуть список [3, 6, 9, 12, 4, 8, 1, 7, 2, 11, 5, 10]
#
# **Tests**
#
# N = 27, K = 6, result = [6, 12, 18, 24, 3, 10, 17, 25, 5, 14, 22, 4, 15, 26, 9, 21, 8, 23, 13, 2, 27, 20, 1, 11, 7, 19, 16]
#
# N = 3, K = 1, result = [1, 2, 3]
#
# N = 7, K = 2, result = [2, 4, 6, 1, 5, 3, 7]
#
# N = 9, K = 8, result = [8, 7, 9, 2, 5, 4, 1, 6, 3]
#
# N = 12, K = 3, result = [3, 6, 9, 12, 4, 8, 1, 7, 2, 11, 5, 10]

# %% [markdown]
# ### Answer 1

# %%
# ===========Область программирования слушателя ==================

def form_list(N, K):
    res = []
    
    lst = [x for x in range(1, N + 1)]
    i = -1

    while ln := len(lst):
        i = (i + K) % ln
        res.append(lst.pop(i))
        i -= 1
    
    return res

# ==============================================================

# ---------- !!! эту часть не меняем !!! ---------
# N = int(input())
# K = int(input())

# N = 7
# K = 2

# N = 12
# K = 3

N = 27
K = 6

print(form_list(N, K))
# Out:
# [6, 12, 18, 24, 3, 10, 17, 25, 5, 14, 22, 4, 15, 26, 9, 21, 8, 23, 13, 2, 27, 20, 1, 11, 7, 19, 16]

# %% [markdown]
# ### Answer 2

# %%
# ===========Область программирования слушателя ==================

def form_list(N, K):
    res = []
    
    lst = [x for x in range(1, N + 1)]
    i = -1

    while len(lst):
        i = (i + K) % len(lst)
        res.append(lst.pop(i))
        i -= 1
    
    return res

# ==============================================================

# ---------- !!! эту часть не меняем !!! ---------
# N = int(input())
# K = int(input())

# N = 7
# K = 2

# N = 12
# K = 3

N = 27
K = 6

print(form_list(N, K))
# Out:
# [6, 12, 18, 24, 3, 10, 17, 25, 5, 14, 22, 4, 15, 26, 9, 21, 8, 23, 13, 2, 27, 20, 1, 11, 7, 19, 16]
