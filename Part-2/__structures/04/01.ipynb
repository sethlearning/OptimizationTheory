# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
x = np.random.randn(2, 100)
plt.scatter(x[0], x[1])
plt.suptitle('Неопределенность, смоделированная с посощью нормально распределенной С.В.', fontsize=14, y=0)
plt.show()
